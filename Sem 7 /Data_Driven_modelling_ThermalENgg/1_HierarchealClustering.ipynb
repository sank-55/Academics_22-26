# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs # For creating a sample dataset
from scipy.cluster.hierarchy import dendrogram, linkage # For hierarchical clustering visualization
from sklearn.cluster import AgglomerativeClustering # For performing the clustering


# Generate a sample dataset
X, y = make_blobs(n_samples=200, centers=4, random_state=42)

# Alternatively, load your own dataset (e.g., from a CSV)
# import pandas as pd
# data = pd.read_csv('your_data.csv')
# X = data.values

# Create a linkage matrix
linked = linkage(X, method='ward') # 'ward' is a common linkage method
# Plot the dendrogram
plt.figure(figsize=(10, 7))
dendrogram(linked,
           orientation='top',
           distance_sort='descending',
           show_leaf_counts=True)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.show()


# Instantiate and fit the AgglomerativeClustering model
# Choose the number of clusters based on the dendrogram or prior knowledge
n_clusters = 4 # Example: based on the dendrogram's structure
cluster = AgglomerativeClustering(n_clusters=n_clusters, affinity='euclidean', linkage='ward')
labels = cluster.fit_predict(X)


# Plot the clustered data points
plt.figure(figsize=(8, 6))
plt.scatter(X[:,0], X[:,1], c=labels, cmap='viridis', s=50)
plt.title('Hierarchical Clustering Results')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3388717573.py in <cell line: 0>()
#      31 # Choose the number of clusters based on the dendrogram or prior knowledge
#      32 n_clusters = 4 # Example: based on the dendrogram's structure
# ---> 33 cluster = AgglomerativeClustering(n_clusters=n_clusters, affinity='euclidean', linkage='ward')
#      34 labels = cluster.fit_predict(X)
#      35
#
# TypeError: AgglomerativeClustering.__init__() got an unexpected keyword argument 'affinity'
